# %% [markdown]
# # PE vs MPE vs WPE Demo
#
# - Generate synthetic tremor + noise and compute PE/MPE/WPE curves.
# - Compare entropy trends as embedding dimension and delay vary.
# - Plot entropy through time for sliding windows to spot transitions.
