# %% [markdown]
# # Feature Engineering
#
# - Load windowed entropy features (CSV) and explore correlations.
# - Normalise or decorrelate features; try scale subsets for MPE.
# - Prepare train/validation splits for forecasting models.
