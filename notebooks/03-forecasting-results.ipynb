# %% [markdown]
# # Forecasting Results
#
# - Train `PermutationEntropyForecaster` models and inspect ROC/PR curves.
# - Calibrate probabilities and map to green/yellow/red alerts.
# - Evaluate lead time relative to synthetic eruption onset annotations.
