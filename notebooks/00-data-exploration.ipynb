# %% [markdown]
# # Data Exploration
#
# - Inspect raw seismic traces (waveforms, PSDs).
# - Use `pevolc.io.read_waveform` or numpy loading for synthetic traces.
# - Visualise amplitude statistics, gaps, and noise levels before feature extraction.
